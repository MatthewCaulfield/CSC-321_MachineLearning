# %% [markdown]
# # CSC-321: Data Mining and Machine Learning
# # Your Name
# ## Assignment 6: Classification with a neuron
#
# ### Part 1: Perceptron classification
#
# The perceptron, as we saw in class, is the simpliest form of neural network consisting of a single neuron. Because it's so simple, it can only be used for two-class classification problems.
#
# The perceptron is inspired by a single neural cell, called a neuron. This accepts input signals via dendrites. Similarly, the perceptron receives inputs from examples of training data, that we weight and combine in a linear equation, called the activation function.
#
# activation = bias + sum(weight(i) * xi)
#
# You should notice the similarity between this, and the linear regression and logistic regression that we've implemented so far.
#
# Once we've computed the activation, we then transform it into the output value, using a transfer function (such as the step transfer function below)
#
# prediction = 1.0 IF activation >= 0.0, ELSE 0.0
#
# In order for this mechanism to work, we have to estimate the weights given in the activation function. Fortunately, we know how to do that using stochastic gradient descent.
#
# Each epoch, the weights are updated using the equation:
#
# w = w + learning_rate * (expected - predicted) * x
#
# Where you know that (expected - predicted) is the measure of error.
#
# This is enough information for you to implement the following (which will be closely related to previous assignments):
#
# - a predict function
#     - that takes a single instance, and a list of weights, where weights[0] is the bias
# - a stochastic gradient descent function
#     - that takes training data, learning rate and a number of epochs
#     - where the weights are first assigned zero scores, and then iteratively updated based on the formula
#         - w(i) = w(i) + learning_rate * (expected - predicted) * x(i)
#     - where you also update the bias based on the formula:
#         - bias = bias + learning_rate * (expected - predicted)
# - a perceptron function
#     - that takes training set, test set, learning rate and epochs
#     - that learns the weights using SGD
#     - then makes predictions over the test set using these weights
#     - and returns these predictions as a list
#
# I've given you a contrived data set for both your predict function, and for testing your SGD function. I've included sample output below.
#
# Then I want you to apply your classifier to the included sonar dataset, using the parameters given, as well as running a reasonable baseline comparison algorithm. You should perform a 3 fold cross validation. You can find out more about this data set here: https://archive.ics.uci.edu/ml/datasets/Connectionist+Bench+(Sonar,+Mines+vs.+Rocks)
#
# The extra twist here is that the data in the sonar data set should be converted to floats EXCEPT for the class (in the last position in each instance), that we should convert to an integer that represents...what? Currently, the class is a nominal category, and we should convert it to an integer: 1 for one class and 0 for the other. Also we will not normalize this data. Why not?

# %%
# Implement or copy your code here
import statistics
import random
import csv
import math
from collections import Counter


def load_data(filename):
    csvTxt = csv.reader(open(filename))
    data = []
    for row in csvTxt:
        data.append(row)
    return data

def column2Float(dataset,column):
    for instance in dataset:
        instance[column] = float(instance[column])
    return dataset

def mean(listOfValues):
    total = 0
    for num in listOfValues:
        total += num
    return total/len(listOfValues)

def zeroRR(train, test):
    trainY = [i[-1] for i in train]
    testY = [i[-1] for i in test]

    trainYMean = mean(trainY)
    predictions = []
    for i in testY:
        predictions.append(trainYMean)
    return predictions


def rmse_eval(actual, predicted):
    error = 0.0
    for i in range(len(actual)):
        error += (predicted[i] - actual[i])**2
    error = error/len(actual)
    error = error**0.5
    return error

def minmax(dataset):
    listMinMax = []
    for column in range(len(dataset[0])):
        columnData = [dataset[i][column] for i in range(len(dataset))]
        listMinMax.append([min(columnData), max(columnData)])
    return listMinMax

def normalize(dataset, minmax):
    for row in range(len(dataset)):
        for column in range(len(dataset[row])):
            dataset[row][column] = (dataset[row][column] - minmax[column][0]) / (minmax[column][1] - minmax[column][0])

def accuracy(actual, predicted):
    counter = 0
    for i in range(len(actual)):
        if actual[i] == predicted[i]:
            counter += 1
    return counter*100/len(actual)

def zeroRC(train, test):
    trainY = [i[-1] for i in train]
    count = Counter(trainY)
    dataMode = count.most_common(1)[0][0]
    return [dataMode for i in test]

random.seed(1)

def cross_validation_data(dataset, folds):
    dataCopy = dataset[:]
    foldLen = len(dataCopy)//folds
    crossData = []
    for i in range(folds - 1):
        currFold = []
        for j in range(foldLen):
            currData = random.choice(dataCopy)
            currFold.append(currData)
            dataCopy.pop(dataCopy.index(currData))
        crossData.append(currFold)
    currFold = []
    for i in range(len(dataCopy)):
            currData = random.choice(dataCopy)
            currFold.append(currData)
            dataCopy.pop(dataCopy.index(currData))
    crossData.append(currFold)
    return crossData

def predictPer(instance, weights):
    activation = weights[0]
    for i in range(len(instance)-1):
        activation += instance[i]*weights[i+1]
    if activation >= 0:
        return 1.0
    else:
        return 0.0


def sgd_per(dataset, learning_rate, epochs):
    weights = [0 for i in range(len(dataset[0]))]
    for e in range(epochs):
        totalError = 0
        for instance in dataset:
            pred = predictPer(instance, weights)
            error = instance[-1] - pred
            totalError += error**2
            weights[0] += learning_rate*error
            for i in range(1,len(weights)):
                weights[i] += learning_rate*error*instance[i-1]
        print('epoch=', e, 'lrate=', learning_rate, 'error=%.3f' %totalError)
    return weights

def perceptron(train, test, learning_rate, epoch):
    weights = sgd_per(train, learning_rate, epochs)
    print(weights)
    predictions = []
    for entry in test:
        prediction = predictPer(entry, weights)
        predictions.append(round(prediction))
    return predictions




# Contrived data
# Predict should work, given the weights below

def evaluate_algorithm(dataset, algorithm, folds, metric, *args):
    foldedData = cross_validation_data(dataset, folds)
    scores = []
    for i in range(len(foldedData)):
        copyFolded = foldedData[:]
        test_data = copyFolded.pop(i)
        test = [test_data[j][:-1] for j in range(len(test_data))]
        for j in test:
            j.append(None)
        train = []
        for fold in copyFolded:
            train += fold
        predicted = algorithm(train,test, *args)
        actual = [j[-1] for j in test_data]
        result = metric(actual,predicted)
        scores.append(result)

    return scores
dataset = [[2.7810836,2.550537003,0],
    [1.465489372,2.362125076,0],
    [3.396561688,4.400293529,0],
    [1.38807019,1.850220317,0],
    [3.06407232,3.005305973,0],
    [7.627531214,2.759262235,1],
    [5.332441248,2.088626775,1],
    [6.922596716,1.77106367,1],
    [8.675418651,-0.242068655,1],
    [7.673756466,3.508563011,1]]

weights = [-0.1, 0.20653640140000007, -0.23418117710000003]

# Using your SGD function with a learning rate of 0.1, and 5 epochs, should give you:
#
#>epoch=0, lrate=0.100, error=2.000
#>epoch=1, lrate=0.100, error=1.000
#>epoch=2, lrate=0.100, error=0.000
#>epoch=3, lrate=0.100, error=0.000
#>epoch=4, lrate=0.100, error=0.000
#
#[-0.1, 0.20653640140000007, -0.23418117710000003]

weightsTest = sgd_per(dataset, 0.1, 5)
print(weightsTest)


# Parameters for learning over real data

filename = 'sonar.all-data.csv'
sonarData = load_data(filename)
print('Number of Instances:', len(sonarData), 'Number of Features:', len(sonarData[0]))
for column in range(len(sonarData[0])-1):
    column2Float(sonarData, column)
    
def rocketMineClass(data):
    for i in data: 
        if i[-1] == 'R':
            i[-1] = 1
        elif i[-1] == 'M':
            i[-1] = 0
            
rocketMineClass(sonarData)
minmaxSonar = minmax(sonarData)
sonarCopy = sonarData[:]


folds = 3
learning_rate = 0.01
epochs = 500

scores = evaluate_algorithm(sonarCopy, perceptron, folds, accuracy, learning_rate, epochs)
zeroRCScores = evaluate_algorithm(sonarCopy, zeroRC, folds, accuracy)
print('Perceptron:', scores)
print('Perceptron Min: %.3f' % min(scores), 'Perceptron Max: %.3f' % max(scores), 'Perceptron Mean: %.3f' % mean(scores))
print('zeroRC: ', zeroRCScores)
print('zeroRC Min: %.3f' % min(zeroRCScores), 'zeroRC Max: %.3f' % max(zeroRCScores), 'zeroRC Mean: %.3f' % mean(zeroRCScores))
# Out:
# epoch= 0 lrate= 0.1 error=2.000
# epoch= 1 lrate= 0.1 error=1.000
# epoch= 2 lrate= 0.1 error=0.000
# epoch= 3 lrate= 0.1 error=0.000
# epoch= 4 lrate= 0.1 error=0.000
# [-0.1, 0.20653640140000007, -0.23418117710000003]
# Number of Instances: 208 Number of Features: 61
# epoch= 0 lrate= 0.01 error=68.000
# epoch= 1 lrate= 0.01 error=46.000
# epoch= 2 lrate= 0.01 error=49.000
# epoch= 3 lrate= 0.01 error=47.000
# epoch= 4 lrate= 0.01 error=46.000
# epoch= 5 lrate= 0.01 error=37.000
# epoch= 6 lrate= 0.01 error=50.000
# epoch= 7 lrate= 0.01 error=35.000
# epoch= 8 lrate= 0.01 error=35.000
# epoch= 9 lrate= 0.01 error=45.000
# epoch= 10 lrate= 0.01 error=42.000
# epoch= 11 lrate= 0.01 error=36.000
# epoch= 12 lrate= 0.01 error=49.000
# epoch= 13 lrate= 0.01 error=30.000
# epoch= 14 lrate= 0.01 error=39.000
# epoch= 15 lrate= 0.01 error=44.000
# epoch= 16 lrate= 0.01 error=36.000
# epoch= 17 lrate= 0.01 error=38.000
# epoch= 18 lrate= 0.01 error=40.000
# epoch= 19 lrate= 0.01 error=36.000
# epoch= 20 lrate= 0.01 error=46.000
# epoch= 21 lrate= 0.01 error=37.000
# epoch= 22 lrate= 0.01 error=39.000
# epoch= 23 lrate= 0.01 error=30.000
# epoch= 24 lrate= 0.01 error=39.000
# epoch= 25 lrate= 0.01 error=37.000
# epoch= 26 lrate= 0.01 error=39.000
# epoch= 27 lrate= 0.01 error=36.000
# epoch= 28 lrate= 0.01 error=32.000
# epoch= 29 lrate= 0.01 error=35.000
# epoch= 30 lrate= 0.01 error=34.000
# epoch= 31 lrate= 0.01 error=32.000
# epoch= 32 lrate= 0.01 error=26.000
# epoch= 33 lrate= 0.01 error=33.000
# epoch= 34 lrate= 0.01 error=28.000
# epoch= 35 lrate= 0.01 error=28.000
# epoch= 36 lrate= 0.01 error=33.000
# epoch= 37 lrate= 0.01 error=38.000
# epoch= 38 lrate= 0.01 error=30.000
# epoch= 39 lrate= 0.01 error=33.000
# epoch= 40 lrate= 0.01 error=38.000
# epoch= 41 lrate= 0.01 error=36.000
# epoch= 42 lrate= 0.01 error=30.000
# epoch= 381 lrate= 0.01 error=24.000
# epoch= 382 lrate= 0.01 error=20.000
# epoch= 383 lrate= 0.01 error=22.000
# epoch= 384 lrate= 0.01 error=24.000
# epoch= 385 lrate= 0.01 error=18.000
# epoch= 386 lrate= 0.01 error=18.000
# epoch= 387 lrate= 0.01 error=24.000
# epoch= 388 lrate= 0.01 error=13.000
# epoch= 389 lrate= 0.01 error=21.000
# epoch= 390 lrate= 0.01 error=18.000
# epoch= 391 lrate= 0.01 error=24.000
# epoch= 392 lrate= 0.01 error=7.000
# epoch= 393 lrate= 0.01 error=16.000
# epoch= 394 lrate= 0.01 error=25.000
# epoch= 395 lrate= 0.01 error=13.000
# epoch= 396 lrate= 0.01 error=26.000
# epoch= 397 lrate= 0.01 error=16.000
# epoch= 398 lrate= 0.01 error=24.000
# epoch= 399 lrate= 0.01 error=20.000
# epoch= 400 lrate= 0.01 error=9.000
# epoch= 401 lrate= 0.01 error=14.000
# epoch= 402 lrate= 0.01 error=20.000
# epoch= 403 lrate= 0.01 error=28.000
# epoch= 404 lrate= 0.01 error=14.000
# epoch= 405 lrate= 0.01 error=24.000
# epoch= 406 lrate= 0.01 error=22.000
# epoch= 407 lrate= 0.01 error=16.000
# epoch= 408 lrate= 0.01 error=14.000
# epoch= 409 lrate= 0.01 error=18.000
# epoch= 410 lrate= 0.01 error=20.000
# epoch= 411 lrate= 0.01 error=26.000
# epoch= 412 lrate= 0.01 error=21.000
# epoch= 413 lrate= 0.01 error=17.000
# epoch= 414 lrate= 0.01 error=13.000
# epoch= 415 lrate= 0.01 error=19.000
# epoch= 416 lrate= 0.01 error=14.000
# epoch= 417 lrate= 0.01 error=14.000
# epoch= 418 lrate= 0.01 error=19.000
# epoch= 419 lrate= 0.01 error=24.000
# epoch= 420 lrate= 0.01 error=16.000
# epoch= 421 lrate= 0.01 error=28.000
# epoch= 422 lrate= 0.01 error=22.000
# epoch= 423 lrate= 0.01 error=16.000
# epoch= 424 lrate= 0.01 error=20.000
# epoch= 425 lrate= 0.01 error=18.000
# epoch= 426 lrate= 0.01 error=18.000
# epoch= 427 lrate= 0.01 error=16.000
# epoch= 428 lrate= 0.01 error=15.000
# epoch= 429 lrate= 0.01 error=15.000
# epoch= 430 lrate= 0.01 error=14.000
# epoch= 431 lrate= 0.01 error=22.000
# epoch= 432 lrate= 0.01 error=17.000
# epoch= 433 lrate= 0.01 error=25.000
# epoch= 434 lrate= 0.01 error=20.000
# epoch= 435 lrate= 0.01 error=26.000
# epoch= 436 lrate= 0.01 error=18.000
# epoch= 437 lrate= 0.01 error=14.000
# epoch= 438 lrate= 0.01 error=16.000
# epoch= 439 lrate= 0.01 error=20.000
# epoch= 440 lrate= 0.01 error=16.000
# epoch= 441 lrate= 0.01 error=24.000
# epoch= 442 lrate= 0.01 error=24.000
# epoch= 443 lrate= 0.01 error=14.000
# epoch= 444 lrate= 0.01 error=20.000
# epoch= 445 lrate= 0.01 error=24.000
# epoch= 446 lrate= 0.01 error=20.000
# epoch= 447 lrate= 0.01 error=20.000
# epoch= 448 lrate= 0.01 error=20.000
# epoch= 58 lrate= 0.01 error=23.000
# epoch= 59 lrate= 0.01 error=26.000
# epoch= 60 lrate= 0.01 error=25.000
# epoch= 61 lrate= 0.01 error=24.000
# epoch= 62 lrate= 0.01 error=18.000
# epoch= 63 lrate= 0.01 error=27.000
# epoch= 64 lrate= 0.01 error=24.000
# epoch= 65 lrate= 0.01 error=19.000
# epoch= 66 lrate= 0.01 error=20.000
# epoch= 67 lrate= 0.01 error=25.000
# epoch= 68 lrate= 0.01 error=24.000
# epoch= 69 lrate= 0.01 error=24.000
# epoch= 70 lrate= 0.01 error=19.000
# epoch= 71 lrate= 0.01 error=22.000
# epoch= 72 lrate= 0.01 error=24.000
# epoch= 73 lrate= 0.01 error=20.000
# epoch= 74 lrate= 0.01 error=22.000
# epoch= 75 lrate= 0.01 error=26.000
# epoch= 76 lrate= 0.01 error=27.000
# epoch= 77 lrate= 0.01 error=18.000
# epoch= 78 lrate= 0.01 error=24.000
# epoch= 79 lrate= 0.01 error=22.000
# epoch= 80 lrate= 0.01 error=18.000
# epoch= 81 lrate= 0.01 error=24.000
# epoch= 82 lrate= 0.01 error=25.000
# epoch= 83 lrate= 0.01 error=21.000
# epoch= 84 lrate= 0.01 error=26.000
# epoch= 85 lrate= 0.01 error=21.000
# epoch= 86 lrate= 0.01 error=20.000
# epoch= 87 lrate= 0.01 error=24.000
# epoch= 88 lrate= 0.01 error=20.000
# epoch= 89 lrate= 0.01 error=22.000
# epoch= 90 lrate= 0.01 error=29.000
# epoch= 91 lrate= 0.01 error=20.000
# epoch= 92 lrate= 0.01 error=23.000
# epoch= 93 lrate= 0.01 error=23.000
# epoch= 94 lrate= 0.01 error=27.000
# epoch= 95 lrate= 0.01 error=20.000
# epoch= 96 lrate= 0.01 error=20.000
# epoch= 97 lrate= 0.01 error=30.000
# epoch= 98 lrate= 0.01 error=25.000
# epoch= 99 lrate= 0.01 error=22.000
# epoch= 100 lrate= 0.01 error=28.000
# epoch= 101 lrate= 0.01 error=20.000
# epoch= 102 lrate= 0.01 error=19.000
# epoch= 103 lrate= 0.01 error=23.000
# epoch= 104 lrate= 0.01 error=23.000
# epoch= 105 lrate= 0.01 error=25.000
# epoch= 106 lrate= 0.01 error=23.000
# epoch= 107 lrate= 0.01 error=18.000
# epoch= 108 lrate= 0.01 error=18.000
# epoch= 109 lrate= 0.01 error=29.000
# epoch= 110 lrate= 0.01 error=23.000
# epoch= 111 lrate= 0.01 error=27.000
# epoch= 112 lrate= 0.01 error=25.000
# epoch= 113 lrate= 0.01 error=26.000
# epoch= 114 lrate= 0.01 error=23.000
# epoch= 115 lrate= 0.01 error=20.000
# epoch= 116 lrate= 0.01 error=18.000
# epoch= 117 lrate= 0.01 error=19.000
# epoch= 118 lrate= 0.01 error=25.000
# epoch= 119 lrate= 0.01 error=22.000
# epoch= 120 lrate= 0.01 error=26.000
# epoch= 121 lrate= 0.01 error=20.000
# epoch= 122 lrate= 0.01 error=23.000
# epoch= 123 lrate= 0.01 error=28.000
# epoch= 124 lrate= 0.01 error=25.000
# epoch= 125 lrate= 0.01 error=20.000
# epoch= 194 lrate= 0.01 error=17.000
# epoch= 195 lrate= 0.01 error=21.000
# epoch= 196 lrate= 0.01 error=20.000
# epoch= 197 lrate= 0.01 error=16.000
# epoch= 198 lrate= 0.01 error=12.000
# epoch= 199 lrate= 0.01 error=24.000
# epoch= 200 lrate= 0.01 error=21.000
# epoch= 201 lrate= 0.01 error=20.000
# epoch= 202 lrate= 0.01 error=18.000
# epoch= 203 lrate= 0.01 error=14.000
# epoch= 204 lrate= 0.01 error=20.000
# epoch= 205 lrate= 0.01 error=24.000
# epoch= 206 lrate= 0.01 error=21.000
# epoch= 207 lrate= 0.01 error=18.000
# epoch= 208 lrate= 0.01 error=23.000
# epoch= 209 lrate= 0.01 error=20.000
# epoch= 210 lrate= 0.01 error=19.000
# epoch= 211 lrate= 0.01 error=16.000
# epoch= 212 lrate= 0.01 error=24.000
# epoch= 213 lrate= 0.01 error=16.000
# epoch= 214 lrate= 0.01 error=18.000
# epoch= 215 lrate= 0.01 error=26.000
# epoch= 216 lrate= 0.01 error=18.000
# epoch= 217 lrate= 0.01 error=16.000
# epoch= 218 lrate= 0.01 error=23.000
# epoch= 219 lrate= 0.01 error=21.000
# epoch= 220 lrate= 0.01 error=20.000
# epoch= 221 lrate= 0.01 error=18.000
# epoch= 222 lrate= 0.01 error=14.000
# epoch= 223 lrate= 0.01 error=22.000
# epoch= 224 lrate= 0.01 error=26.000
# epoch= 225 lrate= 0.01 error=17.000
# epoch= 226 lrate= 0.01 error=24.000
# epoch= 227 lrate= 0.01 error=20.000
# epoch= 228 lrate= 0.01 error=24.000
# epoch= 229 lrate= 0.01 error=17.000
# epoch= 230 lrate= 0.01 error=18.000
# epoch= 231 lrate= 0.01 error=14.000
# epoch= 232 lrate= 0.01 error=22.000
# epoch= 233 lrate= 0.01 error=18.000
# epoch= 234 lrate= 0.01 error=22.000
# epoch= 235 lrate= 0.01 error=22.000
# epoch= 236 lrate= 0.01 error=29.000
# epoch= 237 lrate= 0.01 error=20.000
# epoch= 238 lrate= 0.01 error=16.000
# epoch= 239 lrate= 0.01 error=19.000
# epoch= 240 lrate= 0.01 error=20.000
# epoch= 241 lrate= 0.01 error=16.000
# epoch= 242 lrate= 0.01 error=16.000
# epoch= 243 lrate= 0.01 error=18.000
# epoch= 244 lrate= 0.01 error=14.000
# epoch= 245 lrate= 0.01 error=20.000
# epoch= 246 lrate= 0.01 error=20.000
# epoch= 247 lrate= 0.01 error=28.000
# epoch= 248 lrate= 0.01 error=23.000
# epoch= 249 lrate= 0.01 error=27.000
# epoch= 250 lrate= 0.01 error=16.000
# epoch= 251 lrate= 0.01 error=19.000
# epoch= 252 lrate= 0.01 error=16.000
# epoch= 253 lrate= 0.01 error=12.000
# epoch= 254 lrate= 0.01 error=22.000
# epoch= 255 lrate= 0.01 error=12.000
# epoch= 256 lrate= 0.01 error=18.000
# epoch= 257 lrate= 0.01 error=24.000
# epoch= 258 lrate= 0.01 error=16.000
# epoch= 259 lrate= 0.01 error=22.000
# epoch= 260 lrate= 0.01 error=17.000
# epoch= 261 lrate= 0.01 error=24.000
# epoch= 262 lrate= 0.01 error=20.000
# epoch= 263 lrate= 0.01 error=21.000
# epoch= 264 lrate= 0.01 error=24.000
# epoch= 265 lrate= 0.01 error=18.000
# epoch= 266 lrate= 0.01 error=16.000
# epoch= 267 lrate= 0.01 error=20.000
# epoch= 268 lrate= 0.01 error=20.000
# epoch= 269 lrate= 0.01 error=16.000
# epoch= 270 lrate= 0.01 error=20.000
# epoch= 271 lrate= 0.01 error=18.000
# epoch= 272 lrate= 0.01 error=14.000
# epoch= 273 lrate= 0.01 error=16.000
# epoch= 274 lrate= 0.01 error=18.000
# epoch= 275 lrate= 0.01 error=19.000
# epoch= 276 lrate= 0.01 error=14.000
# epoch= 277 lrate= 0.01 error=12.000
# epoch= 278 lrate= 0.01 error=20.000
# epoch= 279 lrate= 0.01 error=18.000
# epoch= 280 lrate= 0.01 error=20.000
# epoch= 281 lrate= 0.01 error=22.000
# epoch= 282 lrate= 0.01 error=18.000
# epoch= 283 lrate= 0.01 error=16.000
# epoch= 284 lrate= 0.01 error=14.000
# epoch= 285 lrate= 0.01 error=21.000
# epoch= 286 lrate= 0.01 error=16.000
# epoch= 287 lrate= 0.01 error=18.000
# epoch= 288 lrate= 0.01 error=18.000
# epoch= 289 lrate= 0.01 error=12.000
# epoch= 290 lrate= 0.01 error=14.000
# epoch= 291 lrate= 0.01 error=22.000
# epoch= 292 lrate= 0.01 error=20.000
# epoch= 293 lrate= 0.01 error=22.000
# epoch= 294 lrate= 0.01 error=17.000
# epoch= 295 lrate= 0.01 error=16.000
# epoch= 296 lrate= 0.01 error=14.000
# epoch= 297 lrate= 0.01 error=14.000
# epoch= 298 lrate= 0.01 error=22.000
# epoch= 299 lrate= 0.01 error=16.000
# epoch= 300 lrate= 0.01 error=20.000
# epoch= 301 lrate= 0.01 error=14.000
# epoch= 302 lrate= 0.01 error=15.000
# epoch= 303 lrate= 0.01 error=14.000
# epoch= 304 lrate= 0.01 error=18.000
# epoch= 305 lrate= 0.01 error=20.000
# epoch= 306 lrate= 0.01 error=23.000
# epoch= 307 lrate= 0.01 error=15.000
# epoch= 308 lrate= 0.01 error=10.000
# epoch= 309 lrate= 0.01 error=22.000
# epoch= 310 lrate= 0.01 error=18.000
# epoch= 311 lrate= 0.01 error=18.000
# epoch= 312 lrate= 0.01 error=18.000
# epoch= 313 lrate= 0.01 error=20.000
# epoch= 314 lrate= 0.01 error=24.000
# epoch= 315 lrate= 0.01 error=15.000
# epoch= 316 lrate= 0.01 error=22.000
# epoch= 317 lrate= 0.01 error=12.000
# epoch= 318 lrate= 0.01 error=20.000
# epoch= 319 lrate= 0.01 error=20.000
# epoch= 320 lrate= 0.01 error=18.000
# epoch= 321 lrate= 0.01 error=20.000
# epoch= 322 lrate= 0.01 error=26.000
# epoch= 323 lrate= 0.01 error=17.000
# epoch= 324 lrate= 0.01 error=23.000
# epoch= 325 lrate= 0.01 error=20.000
# epoch= 326 lrate= 0.01 error=23.000
# epoch= 327 lrate= 0.01 error=23.000
# epoch= 328 lrate= 0.01 error=28.000
# epoch= 329 lrate= 0.01 error=20.000
# epoch= 330 lrate= 0.01 error=19.000
# epoch= 331 lrate= 0.01 error=18.000
# epoch= 332 lrate= 0.01 error=19.000
# epoch= 333 lrate= 0.01 error=17.000
# epoch= 334 lrate= 0.01 error=20.000
# epoch= 335 lrate= 0.01 error=22.000
# epoch= 336 lrate= 0.01 error=18.000
# epoch= 337 lrate= 0.01 error=14.000
# epoch= 338 lrate= 0.01 error=18.000
# epoch= 339 lrate= 0.01 error=26.000
# epoch= 340 lrate= 0.01 error=19.000
# epoch= 341 lrate= 0.01 error=18.000
# epoch= 342 lrate= 0.01 error=22.000
# epoch= 343 lrate= 0.01 error=18.000
# epoch= 344 lrate= 0.01 error=16.000
# epoch= 345 lrate= 0.01 error=17.000
# epoch= 346 lrate= 0.01 error=13.000
# epoch= 347 lrate= 0.01 error=18.000
# epoch= 348 lrate= 0.01 error=20.000
# epoch= 349 lrate= 0.01 error=20.000
# epoch= 350 lrate= 0.01 error=17.000
# epoch= 351 lrate= 0.01 error=16.000
# epoch= 352 lrate= 0.01 error=16.000
# epoch= 353 lrate= 0.01 error=17.000
# epoch= 354 lrate= 0.01 error=16.000
# epoch= 355 lrate= 0.01 error=18.000
# epoch= 356 lrate= 0.01 error=18.000
# epoch= 357 lrate= 0.01 error=14.000
# epoch= 358 lrate= 0.01 error=16.000
# epoch= 359 lrate= 0.01 error=18.000
# epoch= 360 lrate= 0.01 error=18.000
# epoch= 361 lrate= 0.01 error=16.000
# epoch= 362 lrate= 0.01 error=13.000
# epoch= 363 lrate= 0.01 error=16.000
# epoch= 364 lrate= 0.01 error=16.000
# epoch= 365 lrate= 0.01 error=24.000
# epoch= 366 lrate= 0.01 error=14.000
# epoch= 367 lrate= 0.01 error=16.000
# epoch= 368 lrate= 0.01 error=12.000
# epoch= 369 lrate= 0.01 error=20.000
# epoch= 370 lrate= 0.01 error=20.000
# epoch= 371 lrate= 0.01 error=22.000
# epoch= 372 lrate= 0.01 error=22.000
# epoch= 373 lrate= 0.01 error=16.000
# epoch= 374 lrate= 0.01 error=24.000
# epoch= 375 lrate= 0.01 error=20.000
# epoch= 376 lrate= 0.01 error=18.000
# epoch= 377 lrate= 0.01 error=20.000
# epoch= 378 lrate= 0.01 error=10.000
# epoch= 379 lrate= 0.01 error=20.000
# epoch= 380 lrate= 0.01 error=22.000
# epoch= 381 lrate= 0.01 error=16.000
# epoch= 382 lrate= 0.01 error=28.000
# epoch= 383 lrate= 0.01 error=24.000
# epoch= 384 lrate= 0.01 error=20.000
# epoch= 385 lrate= 0.01 error=18.000
# epoch= 386 lrate= 0.01 error=18.000
# epoch= 387 lrate= 0.01 error=19.000
# epoch= 388 lrate= 0.01 error=20.000
# epoch= 389 lrate= 0.01 error=18.000
# epoch= 390 lrate= 0.01 error=18.000
# epoch= 391 lrate= 0.01 error=12.000
# epoch= 392 lrate= 0.01 error=18.000
# epoch= 393 lrate= 0.01 error=16.000
# epoch= 394 lrate= 0.01 error=18.000
# epoch= 395 lrate= 0.01 error=18.000
# epoch= 396 lrate= 0.01 error=20.000
# epoch= 397 lrate= 0.01 error=20.000
# epoch= 398 lrate= 0.01 error=22.000
# epoch= 399 lrate= 0.01 error=21.000
# epoch= 400 lrate= 0.01 error=21.000
# epoch= 401 lrate= 0.01 error=14.000
# epoch= 402 lrate= 0.01 error=12.000
# epoch= 403 lrate= 0.01 error=18.000
# epoch= 404 lrate= 0.01 error=20.000
# epoch= 405 lrate= 0.01 error=22.000
# epoch= 406 lrate= 0.01 error=18.000
# epoch= 407 lrate= 0.01 error=24.000
# epoch= 408 lrate= 0.01 error=16.000
# epoch= 409 lrate= 0.01 error=15.000
# epoch= 410 lrate= 0.01 error=14.000
# epoch= 411 lrate= 0.01 error=20.000
# epoch= 412 lrate= 0.01 error=20.000
# epoch= 413 lrate= 0.01 error=12.000
# epoch= 414 lrate= 0.01 error=16.000
# epoch= 415 lrate= 0.01 error=18.000
# epoch= 416 lrate= 0.01 error=20.000
# epoch= 417 lrate= 0.01 error=12.000
# epoch= 418 lrate= 0.01 error=14.000
# epoch= 419 lrate= 0.01 error=22.000
# epoch= 420 lrate= 0.01 error=20.000
# epoch= 421 lrate= 0.01 error=15.000
# epoch= 422 lrate= 0.01 error=21.000
# epoch= 423 lrate= 0.01 error=16.000
# epoch= 424 lrate= 0.01 error=18.000
# epoch= 425 lrate= 0.01 error=14.000
# epoch= 426 lrate= 0.01 error=16.000
# epoch= 427 lrate= 0.01 error=18.000
# epoch= 428 lrate= 0.01 error=18.000
# epoch= 429 lrate= 0.01 error=14.000
# epoch= 430 lrate= 0.01 error=20.000
# epoch= 431 lrate= 0.01 error=20.000
# epoch= 432 lrate= 0.01 error=20.000
# epoch= 433 lrate= 0.01 error=18.000
# epoch= 434 lrate= 0.01 error=17.000
# epoch= 435 lrate= 0.01 error=18.000
# epoch= 436 lrate= 0.01 error=16.000
# epoch= 437 lrate= 0.01 error=16.000
# epoch= 438 lrate= 0.01 error=18.000
# epoch= 439 lrate= 0.01 error=14.000
# epoch= 440 lrate= 0.01 error=17.000
# epoch= 441 lrate= 0.01 error=16.000
# epoch= 442 lrate= 0.01 error=23.000
# epoch= 443 lrate= 0.01 error=22.000
# epoch= 444 lrate= 0.01 error=18.000
# epoch= 445 lrate= 0.01 error=18.000
# epoch= 446 lrate= 0.01 error=20.000
# epoch= 447 lrate= 0.01 error=20.000
# epoch= 448 lrate= 0.01 error=20.000
# epoch= 449 lrate= 0.01 error=14.000
# epoch= 450 lrate= 0.01 error=18.000
# epoch= 451 lrate= 0.01 error=16.000
# epoch= 452 lrate= 0.01 error=20.000
# epoch= 453 lrate= 0.01 error=17.000
# epoch= 454 lrate= 0.01 error=16.000
# epoch= 455 lrate= 0.01 error=16.000
# epoch= 456 lrate= 0.01 error=14.000
# epoch= 457 lrate= 0.01 error=22.000
# epoch= 458 lrate= 0.01 error=14.000
# epoch= 459 lrate= 0.01 error=14.000
# epoch= 460 lrate= 0.01 error=22.000
# epoch= 461 lrate= 0.01 error=17.000
# epoch= 462 lrate= 0.01 error=14.000
# epoch= 463 lrate= 0.01 error=16.000
# epoch= 464 lrate= 0.01 error=20.000
# epoch= 465 lrate= 0.01 error=18.000
# epoch= 466 lrate= 0.01 error=17.000
# epoch= 467 lrate= 0.01 error=16.000
# epoch= 468 lrate= 0.01 error=18.000
# epoch= 469 lrate= 0.01 error=16.000
# epoch= 470 lrate= 0.01 error=20.000
# epoch= 471 lrate= 0.01 error=18.000
# epoch= 472 lrate= 0.01 error=20.000
# epoch= 473 lrate= 0.01 error=16.000
# epoch= 474 lrate= 0.01 error=16.000
# epoch= 475 lrate= 0.01 error=18.000
# epoch= 476 lrate= 0.01 error=12.000
# epoch= 477 lrate= 0.01 error=16.000
# epoch= 478 lrate= 0.01 error=13.000
# epoch= 479 lrate= 0.01 error=17.000
# epoch= 480 lrate= 0.01 error=20.000
# epoch= 481 lrate= 0.01 error=19.000
# epoch= 482 lrate= 0.01 error=18.000
# epoch= 483 lrate= 0.01 error=16.000
# epoch= 484 lrate= 0.01 error=16.000
# epoch= 485 lrate= 0.01 error=17.000
# epoch= 486 lrate= 0.01 error=16.000
# epoch= 487 lrate= 0.01 error=16.000
# epoch= 488 lrate= 0.01 error=23.000
# epoch= 489 lrate= 0.01 error=16.000
# epoch= 490 lrate= 0.01 error=20.000
# epoch= 491 lrate= 0.01 error=16.000
# epoch= 492 lrate= 0.01 error=17.000
# epoch= 493 lrate= 0.01 error=16.000
# epoch= 494 lrate= 0.01 error=16.000
# epoch= 495 lrate= 0.01 error=20.000
# epoch= 496 lrate= 0.01 error=16.000
# epoch= 497 lrate= 0.01 error=16.000
# epoch= 498 lrate= 0.01 error=18.000
# epoch= 499 lrate= 0.01 error=16.000
# [0.6100000000000003, -0.2597800000000132, -0.12186600000000032, -0.10189900000000689, 0.06430299999999847, -0.080734000000002, -0.20609999999999856, 0.43408100000000305, 0.26669500000000684, -0.3858459999999922, -0.08455400000000346, -0.4510089999999839, -0.13153300000000162, -0.20083899999999466, 0.36150200000001326, -0.22903999999999533, -0.0024540000000012052, 0.43897500000001405, -0.30752299999999577, -0.0014840000000005266, -0.39130600000002136, 0.2510839999999935, -0.32320499999999414, 0.11785300000000244, -0.05475500000000036, -0.4717489999999778, 0.34044000000000224, 0.00811099999999801, 0.013318999999999474, -0.08999100000000448, -0.21158499999998573, 0.34701599999996835, -0.2047270000000108, -0.2334699999999985, 0.6300940000000046, -0.46358399999997985, 0.21285500000000002, 0.2996610000000016, -0.37845899999997945, -0.07184299999999974, 0.11957899999999738, -0.09006799999999872, -0.013553999999998803, -0.3885570000000155, 0.09993399999999568, 0.16092299999999737, 0.1316790000000007, -0.508040000000003, -0.2749620000000002, -0.16046800000000225, 0.17297600000000096, -0.12678299999999945, -0.12625999999999574, -0.10426699999999861, -0.03377499999999857, 0.16934200000000324, -0.011015999999999995, 0.0906530000000021, 0.0021110000000004302, -0.06172900000000209, -0.0200899999999989]
# epoch= 0 lrate= 0.01 error=66.000
# epoch= 1 lrate= 0.01 error=50.000
# epoch= 2 lrate= 0.01 error=52.000
# epoch= 3 lrate= 0.01 error=41.000
# epoch= 4 lrate= 0.01 error=47.000
# epoch= 5 lrate= 0.01 error=37.000
# epoch= 73 lrate= 0.01 error=24.000
# epoch= 74 lrate= 0.01 error=28.000
# epoch= 75 lrate= 0.01 error=29.000
# epoch= 76 lrate= 0.01 error=25.000
# epoch= 77 lrate= 0.01 error=37.000
# epoch= 78 lrate= 0.01 error=34.000
# epoch= 79 lrate= 0.01 error=24.000
# epoch= 80 lrate= 0.01 error=30.000
# epoch= 81 lrate= 0.01 error=26.000
# epoch= 82 lrate= 0.01 error=24.000
# epoch= 83 lrate= 0.01 error=22.000
# epoch= 84 lrate= 0.01 error=24.000
# epoch= 85 lrate= 0.01 error=26.000
# epoch= 86 lrate= 0.01 error=22.000
# epoch= 87 lrate= 0.01 error=26.000
# epoch= 88 lrate= 0.01 error=30.000
# epoch= 89 lrate= 0.01 error=22.000
# epoch= 90 lrate= 0.01 error=24.000
# epoch= 91 lrate= 0.01 error=29.000
# epoch= 92 lrate= 0.01 error=26.000
# epoch= 93 lrate= 0.01 error=24.000
# epoch= 94 lrate= 0.01 error=20.000
# epoch= 95 lrate= 0.01 error=20.000
# epoch= 96 lrate= 0.01 error=28.000
# epoch= 97 lrate= 0.01 error=23.000
# epoch= 98 lrate= 0.01 error=19.000
# epoch= 99 lrate= 0.01 error=20.000
# epoch= 100 lrate= 0.01 error=26.000
# epoch= 101 lrate= 0.01 error=26.000
# epoch= 102 lrate= 0.01 error=20.000
# epoch= 103 lrate= 0.01 error=31.000
# epoch= 104 lrate= 0.01 error=22.000
# epoch= 105 lrate= 0.01 error=18.000
# epoch= 106 lrate= 0.01 error=24.000
# epoch= 107 lrate= 0.01 error=20.000
# epoch= 108 lrate= 0.01 error=16.000
# epoch= 109 lrate= 0.01 error=38.000
# epoch= 110 lrate= 0.01 error=18.000
# epoch= 111 lrate= 0.01 error=24.000
# epoch= 112 lrate= 0.01 error=20.000
# epoch= 113 lrate= 0.01 error=24.000
# epoch= 114 lrate= 0.01 error=22.000
# epoch= 115 lrate= 0.01 error=29.000
# epoch= 116 lrate= 0.01 error=20.000
# epoch= 117 lrate= 0.01 error=20.000
# epoch= 118 lrate= 0.01 error=20.000
# epoch= 119 lrate= 0.01 error=26.000
# epoch= 120 lrate= 0.01 error=20.000
# epoch= 121 lrate= 0.01 error=30.000
# epoch= 122 lrate= 0.01 error=30.000
# epoch= 123 lrate= 0.01 error=16.000
# epoch= 124 lrate= 0.01 error=18.000
# epoch= 125 lrate= 0.01 error=24.000
# epoch= 126 lrate= 0.01 error=22.000
# epoch= 127 lrate= 0.01 error=19.000
# epoch= 128 lrate= 0.01 error=17.000
# epoch= 129 lrate= 0.01 error=23.000
# epoch= 130 lrate= 0.01 error=21.000
# epoch= 131 lrate= 0.01 error=18.000
# epoch= 132 lrate= 0.01 error=22.000
# epoch= 133 lrate= 0.01 error=12.000
# epoch= 134 lrate= 0.01 error=14.000
# epoch= 135 lrate= 0.01 error=29.000
# epoch= 136 lrate= 0.01 error=23.000
# epoch= 137 lrate= 0.01 error=15.000
# epoch= 138 lrate= 0.01 error=24.000
# epoch= 139 lrate= 0.01 error=26.000
# epoch= 140 lrate= 0.01 error=26.000
# epoch= 141 lrate= 0.01 error=18.000
# epoch= 142 lrate= 0.01 error=20.000
# epoch= 143 lrate= 0.01 error=14.000
# epoch= 144 lrate= 0.01 error=20.000
# epoch= 145 lrate= 0.01 error=19.000
# epoch= 146 lrate= 0.01 error=17.000
# epoch= 147 lrate= 0.01 error=22.000
# epoch= 148 lrate= 0.01 error=20.000
# epoch= 149 lrate= 0.01 error=20.000
# epoch= 150 lrate= 0.01 error=18.000
# epoch= 151 lrate= 0.01 error=20.000
# epoch= 152 lrate= 0.01 error=22.000
# epoch= 153 lrate= 0.01 error=21.000
# epoch= 154 lrate= 0.01 error=15.000
# epoch= 155 lrate= 0.01 error=22.000
# epoch= 156 lrate= 0.01 error=29.000
# epoch= 157 lrate= 0.01 error=18.000
# epoch= 158 lrate= 0.01 error=14.000
# epoch= 159 lrate= 0.01 error=16.000
# epoch= 160 lrate= 0.01 error=18.000
# epoch= 161 lrate= 0.01 error=26.000
# epoch= 162 lrate= 0.01 error=25.000
# epoch= 163 lrate= 0.01 error=26.000
# epoch= 164 lrate= 0.01 error=24.000
# epoch= 165 lrate= 0.01 error=15.000
# epoch= 166 lrate= 0.01 error=17.000
# epoch= 167 lrate= 0.01 error=20.000
# epoch= 168 lrate= 0.01 error=17.000
# epoch= 169 lrate= 0.01 error=21.000
# epoch= 170 lrate= 0.01 error=17.000
# epoch= 171 lrate= 0.01 error=18.000
# epoch= 172 lrate= 0.01 error=18.000
# epoch= 173 lrate= 0.01 error=16.000
# epoch= 174 lrate= 0.01 error=15.000
# epoch= 175 lrate= 0.01 error=23.000
# epoch= 176 lrate= 0.01 error=14.000
# epoch= 177 lrate= 0.01 error=25.000
# epoch= 178 lrate= 0.01 error=17.000
# epoch= 179 lrate= 0.01 error=15.000
# epoch= 180 lrate= 0.01 error=20.000
# epoch= 181 lrate= 0.01 error=18.000
# epoch= 182 lrate= 0.01 error=20.000
# epoch= 183 lrate= 0.01 error=18.000
# epoch= 184 lrate= 0.01 error=18.000
# epoch= 185 lrate= 0.01 error=18.000
# epoch= 186 lrate= 0.01 error=20.000
# epoch= 187 lrate= 0.01 error=18.000
# epoch= 188 lrate= 0.01 error=20.000
# epoch= 189 lrate= 0.01 error=20.000
# epoch= 190 lrate= 0.01 error=18.000
# epoch= 191 lrate= 0.01 error=23.000
# epoch= 192 lrate= 0.01 error=15.000
# epoch= 193 lrate= 0.01 error=18.000
# epoch= 194 lrate= 0.01 error=19.000
# epoch= 195 lrate= 0.01 error=19.000
# epoch= 196 lrate= 0.01 error=18.000
# epoch= 197 lrate= 0.01 error=24.000
# epoch= 198 lrate= 0.01 error=18.000
# epoch= 199 lrate= 0.01 error=22.000
# epoch= 200 lrate= 0.01 error=24.000
# epoch= 201 lrate= 0.01 error=16.000
# epoch= 202 lrate= 0.01 error=20.000
# epoch= 203 lrate= 0.01 error=18.000
# epoch= 204 lrate= 0.01 error=28.000
# epoch= 205 lrate= 0.01 error=14.000
# epoch= 206 lrate= 0.01 error=24.000
# epoch= 207 lrate= 0.01 error=27.000
# epoch= 208 lrate= 0.01 error=15.000
# epoch= 209 lrate= 0.01 error=22.000
# epoch= 210 lrate= 0.01 error=18.000
# epoch= 211 lrate= 0.01 error=22.000
# epoch= 212 lrate= 0.01 error=16.000
# epoch= 213 lrate= 0.01 error=20.000
# epoch= 214 lrate= 0.01 error=24.000
# epoch= 215 lrate= 0.01 error=16.000
# epoch= 216 lrate= 0.01 error=18.000
# epoch= 217 lrate= 0.01 error=18.000
# epoch= 218 lrate= 0.01 error=23.000
# epoch= 219 lrate= 0.01 error=24.000
# epoch= 220 lrate= 0.01 error=12.000
# epoch= 221 lrate= 0.01 error=13.000
# epoch= 222 lrate= 0.01 error=11.000
# epoch= 223 lrate= 0.01 error=15.000
# epoch= 224 lrate= 0.01 error=17.000
# epoch= 225 lrate= 0.01 error=18.000
# epoch= 226 lrate= 0.01 error=15.000
# epoch= 227 lrate= 0.01 error=15.000
# epoch= 228 lrate= 0.01 error=20.000
# epoch= 229 lrate= 0.01 error=20.000
# epoch= 230 lrate= 0.01 error=19.000
# epoch= 231 lrate= 0.01 error=17.000
# epoch= 232 lrate= 0.01 error=16.000
# epoch= 233 lrate= 0.01 error=18.000
# epoch= 234 lrate= 0.01 error=20.000
# epoch= 235 lrate= 0.01 error=18.000
# epoch= 236 lrate= 0.01 error=20.000
# epoch= 237 lrate= 0.01 error=16.000
# epoch= 238 lrate= 0.01 error=20.000
# epoch= 239 lrate= 0.01 error=14.000
# epoch= 240 lrate= 0.01 error=18.000
# epoch= 241 lrate= 0.01 error=20.000
# epoch= 242 lrate= 0.01 error=12.000
# epoch= 243 lrate= 0.01 error=21.000
# epoch= 244 lrate= 0.01 error=18.000
# epoch= 245 lrate= 0.01 error=17.000
# epoch= 246 lrate= 0.01 error=11.000
# epoch= 247 lrate= 0.01 error=16.000
# epoch= 248 lrate= 0.01 error=22.000
# epoch= 249 lrate= 0.01 error=20.000
# epoch= 250 lrate= 0.01 error=13.000
# epoch= 251 lrate= 0.01 error=15.000
# epoch= 252 lrate= 0.01 error=20.000
# epoch= 253 lrate= 0.01 error=14.000
# epoch= 254 lrate= 0.01 error=18.000
# epoch= 255 lrate= 0.01 error=22.000
# epoch= 256 lrate= 0.01 error=16.000
# epoch= 257 lrate= 0.01 error=16.000
# epoch= 258 lrate= 0.01 error=21.000
# epoch= 259 lrate= 0.01 error=17.000
# epoch= 260 lrate= 0.01 error=16.000
# epoch= 261 lrate= 0.01 error=18.000
# epoch= 262 lrate= 0.01 error=22.000
# epoch= 263 lrate= 0.01 error=18.000
# epoch= 264 lrate= 0.01 error=18.000
# epoch= 265 lrate= 0.01 error=25.000
# epoch= 266 lrate= 0.01 error=20.000
# epoch= 267 lrate= 0.01 error=24.000
# epoch= 268 lrate= 0.01 error=12.000
# epoch= 269 lrate= 0.01 error=16.000
# epoch= 270 lrate= 0.01 error=15.000
# epoch= 271 lrate= 0.01 error=13.000
# epoch= 272 lrate= 0.01 error=14.000
# epoch= 273 lrate= 0.01 error=14.000
# epoch= 274 lrate= 0.01 error=18.000
# epoch= 275 lrate= 0.01 error=18.000
# epoch= 276 lrate= 0.01 error=13.000
# epoch= 277 lrate= 0.01 error=17.000
# epoch= 278 lrate= 0.01 error=15.000
# epoch= 279 lrate= 0.01 error=15.000
# epoch= 280 lrate= 0.01 error=16.000
# epoch= 281 lrate= 0.01 error=14.000
# epoch= 282 lrate= 0.01 error=17.000
# epoch= 283 lrate= 0.01 error=22.000
# epoch= 284 lrate= 0.01 error=12.000
# epoch= 285 lrate= 0.01 error=16.000
# epoch= 286 lrate= 0.01 error=16.000
# epoch= 287 lrate= 0.01 error=20.000
# epoch= 288 lrate= 0.01 error=12.000
# epoch= 289 lrate= 0.01 error=12.000
# epoch= 290 lrate= 0.01 error=20.000
# epoch= 291 lrate= 0.01 error=25.000
# epoch= 292 lrate= 0.01 error=19.000
# epoch= 293 lrate= 0.01 error=13.000
# epoch= 294 lrate= 0.01 error=11.000
# epoch= 295 lrate= 0.01 error=14.000
# epoch= 296 lrate= 0.01 error=16.000
# epoch= 297 lrate= 0.01 error=17.000
# epoch= 298 lrate= 0.01 error=13.000
# epoch= 299 lrate= 0.01 error=14.000
# epoch= 300 lrate= 0.01 error=24.000
# epoch= 301 lrate= 0.01 error=16.000
# epoch= 302 lrate= 0.01 error=16.000
# epoch= 303 lrate= 0.01 error=18.000
# epoch= 304 lrate= 0.01 error=18.000
# epoch= 305 lrate= 0.01 error=18.000
# epoch= 306 lrate= 0.01 error=20.000
# epoch= 307 lrate= 0.01 error=18.000
# epoch= 308 lrate= 0.01 error=16.000
# epoch= 309 lrate= 0.01 error=19.000
# epoch= 310 lrate= 0.01 error=22.000
# epoch= 311 lrate= 0.01 error=16.000
# epoch= 312 lrate= 0.01 error=16.000
# epoch= 313 lrate= 0.01 error=16.000
# epoch= 314 lrate= 0.01 error=16.000
# epoch= 315 lrate= 0.01 error=16.000
# epoch= 316 lrate= 0.01 error=24.000
# epoch= 317 lrate= 0.01 error=17.000
# epoch= 318 lrate= 0.01 error=19.000
# epoch= 319 lrate= 0.01 error=16.000
# epoch= 320 lrate= 0.01 error=18.000
# epoch= 321 lrate= 0.01 error=18.000
# epoch= 322 lrate= 0.01 error=12.000
# epoch= 323 lrate= 0.01 error=14.000
# epoch= 324 lrate= 0.01 error=18.000
# epoch= 325 lrate= 0.01 error=12.000
# epoch= 326 lrate= 0.01 error=15.000
# epoch= 327 lrate= 0.01 error=19.000
# epoch= 328 lrate= 0.01 error=14.000
# epoch= 329 lrate= 0.01 error=14.000
# epoch= 330 lrate= 0.01 error=18.000
# epoch= 331 lrate= 0.01 error=24.000
# epoch= 332 lrate= 0.01 error=14.000
# epoch= 333 lrate= 0.01 error=14.000
# epoch= 334 lrate= 0.01 error=18.000
# epoch= 335 lrate= 0.01 error=12.000
# epoch= 336 lrate= 0.01 error=14.000
# epoch= 337 lrate= 0.01 error=12.000
# epoch= 338 lrate= 0.01 error=16.000
# epoch= 339 lrate= 0.01 error=19.000
# epoch= 340 lrate= 0.01 error=26.000
# epoch= 341 lrate= 0.01 error=17.000
# epoch= 342 lrate= 0.01 error=16.000
# epoch= 343 lrate= 0.01 error=12.000
# epoch= 344 lrate= 0.01 error=16.000
# epoch= 345 lrate= 0.01 error=12.000
# epoch= 346 lrate= 0.01 error=20.000
# epoch= 347 lrate= 0.01 error=17.000
# epoch= 348 lrate= 0.01 error=19.000
# epoch= 349 lrate= 0.01 error=16.000
# epoch= 350 lrate= 0.01 error=16.000
# epoch= 351 lrate= 0.01 error=16.000
# epoch= 352 lrate= 0.01 error=16.000
# epoch= 353 lrate= 0.01 error=16.000
# epoch= 354 lrate= 0.01 error=14.000
# epoch= 355 lrate= 0.01 error=16.000
# epoch= 356 lrate= 0.01 error=12.000
# epoch= 357 lrate= 0.01 error=12.000
# epoch= 358 lrate= 0.01 error=22.000
# epoch= 359 lrate= 0.01 error=14.000
# epoch= 360 lrate= 0.01 error=18.000
# epoch= 361 lrate= 0.01 error=18.000
# epoch= 362 lrate= 0.01 error=24.000
# epoch= 363 lrate= 0.01 error=14.000
# epoch= 364 lrate= 0.01 error=23.000
# epoch= 365 lrate= 0.01 error=21.000
# epoch= 366 lrate= 0.01 error=14.000
# epoch= 367 lrate= 0.01 error=22.000
# epoch= 368 lrate= 0.01 error=24.000
# epoch= 369 lrate= 0.01 error=18.000
# epoch= 370 lrate= 0.01 error=16.000
# epoch= 371 lrate= 0.01 error=16.000
# epoch= 372 lrate= 0.01 error=16.000
# epoch= 373 lrate= 0.01 error=22.000
# epoch= 374 lrate= 0.01 error=17.000
# epoch= 375 lrate= 0.01 error=22.000
# epoch= 376 lrate= 0.01 error=22.000
# epoch= 377 lrate= 0.01 error=14.000
# epoch= 378 lrate= 0.01 error=20.000
# epoch= 379 lrate= 0.01 error=13.000
# epoch= 380 lrate= 0.01 error=15.000
# epoch= 381 lrate= 0.01 error=18.000
# epoch= 382 lrate= 0.01 error=17.000
# epoch= 383 lrate= 0.01 error=19.000
# epoch= 384 lrate= 0.01 error=16.000
# epoch= 385 lrate= 0.01 error=16.000
# epoch= 386 lrate= 0.01 error=16.000
# epoch= 387 lrate= 0.01 error=14.000
# epoch= 388 lrate= 0.01 error=18.000
# epoch= 389 lrate= 0.01 error=18.000
# epoch= 390 lrate= 0.01 error=15.000
# epoch= 391 lrate= 0.01 error=16.000
# epoch= 392 lrate= 0.01 error=18.000
# epoch= 393 lrate= 0.01 error=17.000
# epoch= 394 lrate= 0.01 error=18.000
# epoch= 395 lrate= 0.01 error=15.000
# epoch= 396 lrate= 0.01 error=16.000
# epoch= 397 lrate= 0.01 error=19.000
# epoch= 398 lrate= 0.01 error=12.000
# epoch= 399 lrate= 0.01 error=12.000
# epoch= 400 lrate= 0.01 error=15.000
# epoch= 401 lrate= 0.01 error=17.000
# epoch= 402 lrate= 0.01 error=17.000
# epoch= 403 lrate= 0.01 error=19.000
# epoch= 404 lrate= 0.01 error=16.000
# epoch= 405 lrate= 0.01 error=21.000
# epoch= 406 lrate= 0.01 error=12.000
# epoch= 407 lrate= 0.01 error=19.000
# epoch= 408 lrate= 0.01 error=13.000
# epoch= 409 lrate= 0.01 error=19.000
# epoch= 410 lrate= 0.01 error=16.000
# epoch= 411 lrate= 0.01 error=16.000
# epoch= 412 lrate= 0.01 error=14.000
# epoch= 413 lrate= 0.01 error=18.000
# epoch= 414 lrate= 0.01 error=11.000
# epoch= 415 lrate= 0.01 error=21.000
# epoch= 416 lrate= 0.01 error=16.000
# epoch= 417 lrate= 0.01 error=16.000
# epoch= 418 lrate= 0.01 error=24.000
# epoch= 419 lrate= 0.01 error=14.000
# epoch= 420 lrate= 0.01 error=13.000
# epoch= 421 lrate= 0.01 error=19.000
# epoch= 422 lrate= 0.01 error=14.000
# epoch= 423 lrate= 0.01 error=17.000
# epoch= 424 lrate= 0.01 error=19.000
# epoch= 425 lrate= 0.01 error=20.000
# epoch= 426 lrate= 0.01 error=13.000
# epoch= 427 lrate= 0.01 error=17.000
# epoch= 428 lrate= 0.01 error=16.000
# epoch= 429 lrate= 0.01 error=12.000
# epoch= 430 lrate= 0.01 error=16.000
# epoch= 431 lrate= 0.01 error=16.000
# epoch= 432 lrate= 0.01 error=16.000
# epoch= 433 lrate= 0.01 error=19.000
# epoch= 434 lrate= 0.01 error=15.000
# epoch= 435 lrate= 0.01 error=20.000
# epoch= 436 lrate= 0.01 error=20.000
# epoch= 437 lrate= 0.01 error=16.000
# epoch= 438 lrate= 0.01 error=12.000
# epoch= 439 lrate= 0.01 error=15.000
# epoch= 440 lrate= 0.01 error=17.000
# epoch= 441 lrate= 0.01 error=17.000
# epoch= 442 lrate= 0.01 error=15.000
# epoch= 443 lrate= 0.01 error=14.000
# epoch= 444 lrate= 0.01 error=16.000
# epoch= 445 lrate= 0.01 error=16.000
# epoch= 446 lrate= 0.01 error=21.000
# epoch= 447 lrate= 0.01 error=21.000
# epoch= 448 lrate= 0.01 error=16.000
# epoch= 449 lrate= 0.01 error=12.000
# epoch= 450 lrate= 0.01 error=18.000
# epoch= 451 lrate= 0.01 error=16.000
# epoch= 452 lrate= 0.01 error=10.000
# epoch= 453 lrate= 0.01 error=14.000
# epoch= 454 lrate= 0.01 error=16.000
# epoch= 455 lrate= 0.01 error=16.000
# epoch= 456 lrate= 0.01 error=15.000
# epoch= 457 lrate= 0.01 error=15.000
# epoch= 458 lrate= 0.01 error=14.000
# epoch= 459 lrate= 0.01 error=13.000
# epoch= 460 lrate= 0.01 error=19.000
# epoch= 461 lrate= 0.01 error=18.000
# epoch= 462 lrate= 0.01 error=16.000
# epoch= 463 lrate= 0.01 error=16.000
# epoch= 464 lrate= 0.01 error=16.000
# epoch= 465 lrate= 0.01 error=14.000
# epoch= 466 lrate= 0.01 error=12.000
# epoch= 467 lrate= 0.01 error=15.000
# epoch= 468 lrate= 0.01 error=22.000
# epoch= 469 lrate= 0.01 error=12.000
# epoch= 470 lrate= 0.01 error=15.000
# epoch= 471 lrate= 0.01 error=19.000
# epoch= 472 lrate= 0.01 error=14.000
# epoch= 473 lrate= 0.01 error=16.000
# epoch= 474 lrate= 0.01 error=13.000
# epoch= 475 lrate= 0.01 error=16.000
# epoch= 476 lrate= 0.01 error=16.000
# epoch= 477 lrate= 0.01 error=14.000
# epoch= 478 lrate= 0.01 error=17.000
# epoch= 479 lrate= 0.01 error=15.000
# epoch= 480 lrate= 0.01 error=19.000
# epoch= 481 lrate= 0.01 error=10.000
# epoch= 482 lrate= 0.01 error=12.000
# epoch= 483 lrate= 0.01 error=16.000
# epoch= 484 lrate= 0.01 error=17.000
# epoch= 485 lrate= 0.01 error=16.000
# epoch= 486 lrate= 0.01 error=9.000
# epoch= 487 lrate= 0.01 error=16.000
# epoch= 488 lrate= 0.01 error=14.000
# epoch= 489 lrate= 0.01 error=14.000
# epoch= 490 lrate= 0.01 error=14.000
# epoch= 491 lrate= 0.01 error=16.000
# epoch= 492 lrate= 0.01 error=12.000
# epoch= 493 lrate= 0.01 error=12.000
# epoch= 494 lrate= 0.01 error=12.000
# epoch= 495 lrate= 0.01 error=16.000
# epoch= 496 lrate= 0.01 error=12.000
# epoch= 497 lrate= 0.01 error=16.000
# epoch= 498 lrate= 0.01 error=16.000
# epoch= 499 lrate= 0.01 error=14.000
# [0.26000000000000006, -0.10077400000000102, -0.14589100000000157, 0.3475290000000112, -0.6772260000000023, -0.15556299999998954, -0.2576299999999959, 0.045043999999998925, 0.5838859999999984, -0.07774499999999816, 0.26486799999999455, -0.43735100000000543, -0.43572600000000083, -0.11543300000000138, -0.005097000000000905, -0.23188700000000456, 0.31820800000000016, 0.047780999999999504, -0.20275199999999807, 0.3629559999999787, 0.17487999999999654, -0.4398710000000113, 0.12961300000000128, -0.12499699999999835, -0.23164400000000446, 0.326244000000005, -0.24314300000000014, 0.16223000000000343, 0.02098399999999935, 0.09170299999999693, -0.4620119999999986, 0.5623299999999818, -0.33173099999998906, -0.03307399999999864, 0.10626799999999978, -0.12628100000000295, 0.13475899999999438, 0.17046100000000625, 0.015435999999999223, -0.18975299999998585, 0.35658399999999596, -0.2355859999999938, 0.1602550000000026, 0.11840400000000222, -0.03229399999999919, -0.4076180000000214, -0.20881599999998957, 0.06301900000000224, -0.553699999999998, -0.47574899999996395, 0.04818099999999813, -0.1484689999999977, -0.11565499999999551, -0.012477000000000205, -0.04672499999999732, -0.04106700000000113, 0.044639000000000505, -0.01821399999999953, -0.1407269999999943, -0.07813700000000073, -0.09817800000000099]
# Perceptron: [78.26086956521739, 69.56521739130434, 72.85714285714286]
# Perceptron Min: 69.565 Perceptron Max: 78.261 Perceptron Mean: 73.561
# zeroRC:  [52.17391304347826, 47.82608695652174, 40.0]
# zeroRC Min: 40.000 zeroRC Max: 52.174 zeroRC Mean: 46.667

# %% [markdown]
# We do not need to normalize the data for the sonar data set because the data is already between 0 and 1. From using perceptron we see that there are certain angles that are more important in differentiating a rock from a mine the more important angles are weighted close to 0.5 or -0.5 while the least important angles are weighted around 0.08. All other angles are weighted between these between these two extremes. Overall the perceptron has an accuracy of differentiating between a rock and a mine of around 73% which is fairly accurate. However I am not sure if I would trust it with my life. The zeroRC should have worked slightly better considering that there were more instances of mines than rocks in the data set and it had an mean accuracy of 46% its mean accuracy should be above 50%. It may be lower because if the fold was made with equal amounts of rocks and mines it could have chosen rocks while that training data may have had a more accurate split to the overall data making zeroRC work not as well. To work better we should stratisfy the folds. To make each fold more accurate to the overall dataset.
